# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('dispaly.max_columns',100)
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# <ipython-input-10-ecb30a504ea6> in <module>
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 4 pd.set_option('dispaly.max_columns',100)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/config.py in __call__(self, *args, **kwds)
#     225
#     226     def __call__(self, *args, **kwds):
# --> 227         return self.__func__(*args, **kwds)
#     228
#     229     @property
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/config.py in _set_option(*args, **kwargs)
#     117
#     118     for k, v in zip(args[::2], args[1::2]):
# --> 119         key = _get_single_key(k, silent)
#     120
#     121         o = _get_registered_option(key)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/config.py in _get_single_key(pat, silent)
#      81         if not silent:
# ...

# %%
train=pd.read_csv('../input/train_data.csv')
test=pd.read_csv('../input/test_a.csv')

# %%
train.head()
# Out:
#           ID    area rentType houseType houseFloor  totalFloor houseToward  \
# 0  100309852   68.06     未知方式    2室1厅1卫          低          16        暂无数据
# 1  100307942  125.55     未知方式    3室2厅2卫          中          14        暂无数据
# 2  100307764  132.00     未知方式    3室2厅2卫          低          32        暂无数据
# 3  100306518   57.00     未知方式    1室1厅1卫          中          17        暂无数据
# 4  100305262  129.00     未知方式    3室2厅3卫          低           2        暂无数据
#
#   houseDecoration communityName city  ... landTotalPrice landMeanPrice  \
# 0              其他       XQ00051   SH  ...              0        0.0000
# 1              简装       XQ00130   SH  ...              0        0.0000
# 2              其他       XQ00179   SH  ...              0        0.0000
# 3              精装       XQ00313   SH  ...      332760000     3080.0331
# 4              毛坯       XQ01257   SH  ...              0        0.0000
#
#   totalWorkers  newWorkers  residentPopulation      pv     uv  lookNum  \
# ...
